# %%
import pandas as pd

# %%
results = pd.read_json("results.jsonl", lines=True)

records = []
for _, row in results.iterrows():
    record = {
        "subs": row["args"]["subs"],
        "lr": row["args"]["lr"],
        "wd": row["args"]["wd"],
        "acc_train": row["acc_train"],
        "acc_val": row["acc_val"],
        "acc_test": row["acc_test"],
    }
    records.append(record)
df = pd.DataFrame.from_records(records)

print(df.shape)
df.head()
# Out:
# (84, 6)
#   subs       lr     wd  acc_train  acc_val  acc_test
# 0    0  0.00005  0.001     99.241   65.741    63.327
# 1    0  0.00005  0.010     99.838   65.509    62.791
# 2    0  0.00005  0.100     99.952   64.352    62.075
# 3    0  0.00010  0.001     99.984   65.741    62.254
# 4    0  0.00010  0.010     99.984   65.509    64.043

# %%
summary = []
for subs, group in df.groupby("subs"):
    idx = group["acc_val"].idxmax()
    summary.append(group.loc[idx])
summary = pd.DataFrame.from_records(summary)
summary
# Out:
#     subs       lr     wd  acc_train  acc_val  acc_test
# 0      0  0.00020  0.001     99.984   67.361    65.653
# 1  0,1,2  0.00005  0.100     94.462   50.077    51.279
# 2      1  0.00010  0.001    100.000   56.853    56.716
# 3      2  0.00100  0.001    100.000   49.266    51.667

# %%
summary_fmt = summary.copy()
summary_fmt = summary_fmt.loc[[0, 2, 3, 1], ["subs", "acc_val", "acc_test"]]
summary_fmt.columns = ["subjects", "val (testid)", "test (shared1k)"]
print(summary_fmt.to_markdown(index=False))
# Out:
# | subjects   |   val (testid) |   test (shared1k) |
# |:-----------|---------------:|------------------:|
# | 0          |         67.361 |            65.653 |
# | 1          |         56.853 |            56.716 |
# | 2          |         49.266 |            51.667 |
# | 0,1,2      |         50.077 |            51.279 |
